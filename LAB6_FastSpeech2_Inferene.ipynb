# %% [markdown]
# <a href="https://colab.research.google.com/github/june-oh/cseg109/blob/main/LAB6_FastSpeech2_Inferene.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf sample_data .config && ls -alh
# Out:
# total 12K
# drwxr-xr-x 1 root root 4.0K Dec  5 08:12 .
# drwxr-xr-x 1 root root 4.0K Dec  5 08:11 ..

# %%
# !git clone https://github.com/HGU-DLLAB/Korean-FastSpeech2-Pytorch.git .
# Out:
# Cloning into '.'...
# remote: Enumerating objects: 323, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 323 (delta 17), reused 19 (delta 8), pack-reused 286
# Receiving objects: 100% (323/323), 11.43 MiB | 16.86 MiB/s, done.
# Resolving deltas: 100% (171/171), done.

# %%
# !pip install -q g2pk
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 90.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 573.9/573.9 kB 62.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 50.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 18.7 MB/s eta 0:00:00

# %%
#!pip install -r requirements.txt
# Out:
# Processing /workdir/conda-build/six_1593148849096/work (from -r requirements.txt (line 90))
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/workdir/conda-build/six_1593148849096/work'

# %%
# !ls
# Out:
# assets	    evaluate.py     loss.py	      preprocessed	synthesize.py  utils.py
# audio	    fastspeech2.py  modules.py	      preprocess.py	text	       vocoder
# data	    hparams.py	    optimizer.py      README.md		train.py
# dataset.py  LICENSE	    prepare_align.py  requirements.txt	transformer

# %%
# !mkdir -p ./ckpt/kss

# %%
import gdown

url = 'https://drive.google.com/uc?id=1qkFuNLqPIm-A5mZZDPGK1mnp0_Lh00PN'
gdown.download(url, "./ckpt/kss/checkpoint_350000.pth.tar" ,quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1qkFuNLqPIm-A5mZZDPGK1mnp0_Lh00PN
# To: /content/ckpt/kss/checkpoint_350000.pth.tar
# 100%|██████████| 346M/346M [00:05<00:00, 66.7MB/s]
# './ckpt/kss/checkpoint_350000.pth.tar'

# %%
url = 'https://drive.google.com/uc?id=1GxaLlTrEhq0aXFvd_X1f4b-ev7-FH8RB'
gdown.download(url,"./vocoder/pretrained_models/")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1GxaLlTrEhq0aXFvd_X1f4b-ev7-FH8RB
# To: /content/vocoder/pretrained_models/vocgan_kss_pretrained_model_epoch_4500.pt
# 100%|██████████| 109M/109M [00:01<00:00, 95.0MB/s]
# './vocoder/pretrained_models/vocgan_kss_pretrained_model_epoch_4500.pt'

# %%
# !pip install -q librosa==0.8.0
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 13.2 MB/s eta 0:00:00
# ...

# %%
# !python3 synthesize.py --step 350000
# Out:
# /content/text/__init__.py:74: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   return s in _symbol_to_id and s is not '~' and s is not '_'
# /content/text/__init__.py:74: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   return s in _symbol_to_id and s is not '~' and s is not '_'
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# which sentence do you want?
# 1.eval_sentence 2.train_sentence 3.test_sentence 4.create new sentence
# 4
# you went for mode 4
# input sentence
# 신라면도.한사람에게는.작은 한걸음이지만.나에겐.위대한 도약이다
# sentence that will be synthesized:
# 신라면도.한사람에게는.작은 한걸음이지만.나에겐.위대한 도약이다
# 다
# ...

# %%
ls ./results/*.wav
# Out:
# ./results/step_350000-pitch_1.0-energy_1.0_griffin_lim_신라면도.한사람에게.wav
# ./results/step_350000-pitch_1.0-energy_1.0_vocgan_신라면도.한사람에게.wav

# %%
import IPython.display as ipd

# %%
audio_path = "./results/step_350000-pitch_1.0-energy_1.0_vocgan_신라면도.한사람에게.wav"
ipd.Audio(audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
